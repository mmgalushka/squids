# %% [markdown]
# # Synthetic images with blur effect on X and Y axis
#
# This demonstrates generating synthetic images with  blur effect on X and Y (of different level).

# %%
# Let's make sure that JNB can find our SquiDS package ;)
import sys
sys.path.insert(0, '..')

# The random package is needed to set a random state for
# generating consistent images. 
import random

from PIL import ImageDraw

from squids.dataset.image import create_synthetic_image
from squids.dataset.palette import Palette
from squids.dataset.background import Background

# %% [markdown]
# ## Blur on X-axis

# %%
for i in [0,2,4,6,8]:
    blur_level = i / 10.0
    print(f"Blur level: {blur_level}")

    random.seed(365)
    image, shapes = create_synthetic_image(
        image_width=256,
        image_height=256,
        image_palette=Palette.GRAY,
        image_background=Background.BLACK,
        image_capacity=5,
        adding_shapes="r",
        blur_x=blur_level)
    print("Generated image shapes:", list(map(str, shapes)))
    draw = ImageDraw.Draw(image)
    draw.rectangle([0,0, 255, 255], outline="gray")
    image.show()
# Out:
# Blur level: 0.0
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.2
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.4
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.6
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.8
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# ## Blur on Y-axis

# %%
for i in [0,2,4,6,8]:
    blur_level = i / 10.0
    print(f"Blur level: {blur_level}")

    random.seed(365)
    image, shapes = create_synthetic_image(
        image_width=256,
        image_height=256,
        image_palette=Palette.GRAY,
        image_background=Background.BLACK,
        image_capacity=5,
        adding_shapes="r",
        blur_y=blur_level)
    print("Generated image shapes:", list(map(str, shapes)))
    draw = ImageDraw.Draw(image)
    draw.rectangle([0,0, 255, 255], outline="gray")
    image.show()
# Out:
# Blur level: 0.0
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.2
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.4
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.6
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.8
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# ## Blur on XY-axis

# %%
for i in [0,2,4,6,8]:
    blur_level = i / 10.0
    print(f"Blur level: {blur_level}")

    random.seed(365)
    image, shapes = create_synthetic_image(
        image_width=256,
        image_height=256,
        image_palette=Palette.GRAY,
        image_background=Background.BLACK,
        image_capacity=5,
        adding_shapes="r",
        blur_x=blur_level,
        blur_y=blur_level)
    print("Generated image shapes:", list(map(str, shapes)))
    draw = ImageDraw.Draw(image)
    draw.rectangle([0,0, 255, 255], outline="gray")
    image.show()
# Out:
# Blur level: 0.0
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.2
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.4
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.6
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
# Blur level: 0.8
# Generated image shapes: ["Rectangle(bbox=[(130, 99), 102, 49], polygon=[(130, 99), (232, 99), (232, 148), (130, 148)], color='#b3b0a3'", "Rectangle(bbox=[(7, 51), 95, 47], polygon=[(7, 51), (102, 51), (102, 98), (7, 98)], color='#631f84'", "Rectangle(bbox=[(223, 152), 26, 81], polygon=[(223, 152), (249, 152), (249, 233), (223, 233)], color='#99b735'"]
# <PIL.Image.Image image mode=RGB size=256x256>
